# %%
#import Libraries
import pandas as pd

# %%
#read csv
black_friday = pd.read_csv('train_blackFriday.csv')

# %%
#number of rows and coulmns
num_rows, num_cols = black_friday.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_cols}")
# Out:
# Number of rows: 550068
# Number of columns: 12

# %%
#show data types found
print(black_friday.dtypes)
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
#show coulmns
print(black_friday.columns)
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
#Checking NaN values in the given dataset
nanvalues = black_friday.isna().sum()
print(nanvalues)
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
#Checking duplicate values in the dataset

duplicate_rows = black_friday[black_friday.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [User_ID, Product_ID, Gender, Age, Occupation, City_Category, Stay_In_Current_City_Years, Marital_Status, Product_Category_1, Product_Category_2, Product_Category_3, Purchase]
# Index: []

# %%
#Renaming the column name to lower case
black_friday.columns = black_friday.columns.str.lower()
print(black_friday.columns)
# Out:
# Index(['user_id', 'product_id', 'gender', 'age', 'occupation', 'city_category',
#        'stay_in_current_city_years', 'marital_status', 'product_category_1',
#        'product_category_2', 'product_category_3', 'purchase'],
#       dtype='object')

# %%
#Removing Reducant Values (user id)
if 'user id' in black_friday.columns:
    black_friday = black_friday.drop(columns=['user id'])

# %%
#Checking for unique values in each individual column of the dataset

# %%
for column in black_friday.columns:
    unique_values = black_friday[column].unique()

# %%
print(unique_values)
print("-" * 10)
# Out:
# [ 8370 15200  1422 ...   135   123   613]
# ----------

# %%
#replace each range in age coulmn to its creosspond category ex:0-17 ->child ,18-25 ->teenage, 26-50 -> adult , 51-55+ ->old

# %%
black_friday = pd.DataFrame(black_friday)
print (black_friday)
# Out:
#         user_id product_id gender    age  occupation city_category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        stay_in_current_city_years  marital_status  product_category_1  \
# 0                               2               0                   3
# ...

# %%
age = {
    '0-17': 'child',
    '18-25': 'teenage',
    '26-50': 'adult',
    '51-55+': 'old'
}
black_friday['age'] = black_friday['age'].replace(age)

# %%
print(black_friday)
# Out:
#         user_id product_id gender    age  occupation city_category  \
# 0       1000001  P00069042      F  child          10             A
# 1       1000001  P00248942      F  child          10             A
# 2       1000001  P00087842      F  child          10             A
# 3       1000001  P00085442      F  child          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        stay_in_current_city_years  marital_status  product_category_1  \
# 0                               2               0                   3
# ...

# %%
#Checking for unique values for city_years column
if 'stay_in_current_city_years  ' in black_friday.columns:
    unique_city_years = black_friday['stay_in_current_city_years  '].unique()
    print("Unique values in the 'stay_in_current_city_years  ' column:")
    print(unique_city_years)
else:
    print(" The column 'city_years' is not found in the dataset.")
# Out:
#  The column 'city_years' is not found in the dataset.

# %%
#remove + from rows in city_years column

# %%
black_friday = pd.DataFrame(black_friday)

# %%
print("Columns in the dataset:")
print(black_friday.columns)

black_friday.columns = black_friday.columns.str.strip()
if 'stay_in_current_city_years' in black_friday.columns:
    black_friday['stay_in_current_city_years'] = black_friday['stay_in_current_city_years'].str.replace('+', '')

    print(black_friday)
else:
    print("Column 'city_years' not found in the dataset. Check the column names in your CSV file.")
# Out:
# Columns in the dataset:
# Index(['user_id', 'product_id', 'gender', 'age', 'occupation', 'city_category',
#        'stay_in_current_city_years', 'marital_status', 'product_category_1',
#        'product_category_2', 'product_category_3', 'purchase'],
#       dtype='object')
#         user_id product_id gender    age  occupation city_category  \
# 0       1000001  P00069042      F  child          10             A
# 1       1000001  P00248942      F  child          10             A
# 2       1000001  P00087842      F  child          10             A
# 3       1000001  P00085442      F  child          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# ...

# %%
print(black_friday)

# %%
#Checking for unique values for category_1 column
unique_values_category_1 = black_friday['product_category_1'].unique()
print(unique_values_category_1)
# Out:
# [ 3  1 12  8  5  4  2  6 14 11 13 15  7 16 18 10 17  9 20 19]

# %%
#Checking for unique values for category_2 column
unique_values_category_2 = black_friday['product_category_2'].unique()
print(unique_values_category_2)
# Out:
# [nan  6. 14.  2.  8. 15. 16. 11.  5.  3.  4. 12.  9. 10. 17. 13.  7. 18.]

# %%
#fill null you found
null = black_friday.isnull().sum()
print("Null value counts:")
print(null)
black_friday['product_category_2'].fillna('Unknown', inplace=True)
# Out:
# Null value counts:
# user_id                            0
# product_id                         0
# gender                             0
# age                                0
# occupation                         0
# city_category                      0
# stay_in_current_city_years         0
# marital_status                     0
# product_category_1                 0
# product_category_2                 0
# product_category_3            383247
# purchase                           0
# dtype: int64

# %%
#Checking for unique values for category_3 column
unique_values_category_3= black_friday['product_category_3'].unique()
print(unique_values_category_3)
# Out:
# [nan 14. 17.  5.  4. 16. 15.  8.  9. 13.  6. 12.  3. 18. 11. 10.]

# %%
#fill null you found

# %%
null_counts = black_friday.isnull().sum()
print("Null value counts:")
print(null)
black_friday['product_category_3'].fillna('Unknown', inplace=True)
# Out:
# Null value counts:
# user_id                            0
# product_id                         0
# gender                             0
# age                                0
# occupation                         0
# city_category                      0
# stay_in_current_city_years         0
# marital_status                     0
# product_category_1                 0
# product_category_2                 0
# product_category_3            383247
# purchase                           0
# dtype: int64

# %%
#check for null values
null = black_friday.isnull().sum()
print(null)
# Out:
# user_id                       0
# product_id                    0
# gender                        0
# age                           0
# occupation                    0
# city_category                 0
# stay_in_current_city_years    0
# marital_status                0
# product_category_1            0
# product_category_2            0
# product_category_3            0
# purchase                      0
# dtype: int64

# %%
#check for duplicates values
duplicate = black_friday[black_friday.duplicated()]
print(duplicate)
# Out:
# Empty DataFrame
# Columns: [user_id, product_id, gender, age, occupation, city_category, stay_in_current_city_years, marital_status, product_category_1, product_category_2, product_category_3, purchase]
# Index: []
